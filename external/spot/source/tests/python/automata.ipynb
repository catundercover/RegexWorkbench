# %%
from IPython.display import display
import spot
from spot.jupyter import display_inline
spot.setup()

# %% [markdown]
# To build an automaton from an LTL formula, simply call `translate()` with a formula, and a list of options to characterize the automaton you want (those options have the same name as the long options name of the `ltl2tgba` tool, and they can be abbreviated).

# %%
a = spot.translate('(a U b) & GFc & GFd', 'Buchi', 'state-based', 'complete'); a
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f672ab76770> >

# %% [markdown]
# The call the `spot.setup()` in the first cells has installed a default style for the graphviz output.  If you want to change this style temporarily, you can call the `show(style)` method explicitly.  For instance here is a vertical layout with the default font of GraphViz.

# %%
a.show("v")
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.1 (0)
#  -->
# <!-- Pages: 1 -->
# <svg width="346pt" height="360pt"
#  viewBox="0.00 0.00 346.00 360.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.938869 0.938869) rotate(0) translate(4 379.44)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-379.44 364.21,-379.44 364.21,4 -4,4"/>
# <text xml:space="preserve" text-anchor="middle" x="180.11" y="-358.14" font-family="Times,serif" font-size="14.00">[Büchi]</text>
# <!-- I -->
# <!-- 0 -->
# <g id="node2" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="232.21" cy="-293.75" rx="18" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="232.21" y="-289.07" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- I&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>I&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M232.21,-348.6C232.21,-347 232.21,-333.3 232.21,-320.12"/>
# <polygon fill="black" stroke="black" points="232.21,-313.31 235.36,-320.31 232.21,-315.6 232.21,-320.31 232.21,-320.31 232.21,-320.31 232.21,-315.6 229.06,-320.31 232.21,-313.31"/>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M249.25,-300.22C259.07,-301.54 268.21,-299.38 268.21,-293.75 268.21,-289.7 263.49,-287.45 257.19,-286.99"/>
# <polygon fill="black" stroke="black" points="250.47,-287.24 257.35,-283.84 252.75,-287.15 257.46,-286.98 257.46,-286.98 257.46,-286.98 252.75,-287.15 257.58,-290.13 250.47,-287.24"/>
# <text xml:space="preserve" text-anchor="middle" x="290.71" y="-289.07" font-family="Times,serif" font-size="14.00">a &amp; !b</text>
# </g>
# <!-- 1 -->
# <g id="node3" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="81.21" cy="-200.5" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="81.21" cy="-200.5" rx="22" ry="22"/>
# <text xml:space="preserve" text-anchor="middle" x="81.21" y="-195.82" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M213.98,-291.71C188.6,-289.39 142.36,-281.9 112.21,-257.75 102.97,-250.34 96.06,-239.4 91.14,-229.13"/>
# <polygon fill="black" stroke="black" points="88.4,-222.94 94.11,-228.07 89.32,-225.03 91.23,-229.34 91.23,-229.34 91.23,-229.34 89.32,-225.03 88.36,-230.62 88.4,-222.94"/>
# <text xml:space="preserve" text-anchor="middle" x="146.71" y="-244.45" font-family="Times,serif" font-size="14.00">b &amp; c &amp; d</text>
# </g>
# <!-- 2 -->
# <g id="node4" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="133.21" cy="-107.25" rx="18" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="133.21" y="-102.58" font-family="Times,serif" font-size="14.00">2</text>
# </g>
# <!-- 0&#45;&gt;2 -->
# <g id="edge4" class="edge">
# <title>0&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M227.56,-275.96C219.05,-247.11 199.08,-186.98 169.21,-143.25 164.57,-136.45 158.45,-129.9 152.57,-124.34"/>
# <polygon fill="black" stroke="black" points="147.75,-119.96 155.05,-122.33 149.44,-121.5 152.93,-124.67 152.93,-124.67 152.93,-124.67 149.44,-121.5 150.81,-127 147.75,-119.96"/>
# <text xml:space="preserve" text-anchor="middle" x="231.83" y="-195.82" font-family="Times,serif" font-size="14.00">b &amp; !d</text>
# </g>
# <!-- 3 -->
# <g id="node5" class="node">
# <title>3</title>
# <ellipse fill="none" stroke="black" cx="106.21" cy="-18" rx="18" ry="18"/>
# <text xml:space="preserve" text-anchor="middle" x="106.21" y="-13.32" font-family="Times,serif" font-size="14.00">3</text>
# </g>
# <!-- 0&#45;&gt;3 -->
# <g id="edge5" class="edge">
# <title>0&#45;&gt;3</title>
# <path fill="none" stroke="black" d="
class="edge">
# <title>2&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M149.88,-115.09C159.84,-116.84 169.21,-114.22 169.21,-107.25 169.21,-102.24 164.37,-99.48 157.95,-98.97"/>
# <polygon fill="black" stroke="black" points="151.1,-99.34 157.91,-95.82 153.37,-99.22 158.08,-98.96 158.08,-98.96 158.08,-98.96 153.37,-99.22 158.26,-102.11 151.1,-99.34"/>
# <text xml:space="preserve" text-anchor="middle" x="176.71" y="-102.58" font-family="Times,serif" font-size="14.00">!d</text>
# </g>
# <!-- 2&#45;&gt;3 -->
# <g id="edge12" class="edge">
# <title>2&#45;&gt;3</title>
# <path fill="none" stroke="black" d="M128.14,-89.84C124.09,-76.76 118.36,-58.25 113.77,-43.43"/>
# <polygon fill="black" stroke="black" points="111.72,

# %% [markdown]
# If you want to add some style options to the existing one, pass a dot to the `show()` function in addition to your own style options:

# %%
a.show(".st")
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.1 (0)
#  -->
# <!-- Pages: 1 -->
# <svg width="396pt" height="360pt"
#  viewBox="0.00 0.00 396.00 360.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.851064 0.851064) rotate(0) translate(4 419)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-419 461.22,-419 461.22,4 -4,4"/>
# <text xml:space="preserve" text-anchor="start" x="208.74" y="-398.7" font-family="Lato" font-size="14.00">Inf(</text>
# <text xml:space="preserve" text-anchor="start" x="228.99" y="-398.7" font-family="Lato" font-size="14.00" fill="#1f78b4">⓿</text>
# <text xml:space="preserve" text-anchor="start" x="244.74" y="-398.7" font-family="Lato" font-size="14.00">)</text>
# <text xml:space="preserve" text-anchor="start" x="207.24" y="-384.7" font-family="Lato" font-size="14.00">[Büchi]</text>
# <g id="clust1" class="cluster">
# <title>cluster_0</title>
# <polygon fill="none" stroke="green" points="157.97,-160 157.97,-371 449.22,-371 449.22,-160 157.97,-160"/>
# </g>
# <g id="clust2" class="cluster">
# <title>cluster_1</title>
# <polygon fill="none" stroke="grey" points="157.97,-8 157.97,-95 209.97,-95 209.97,-8 157.97,-8"/>
# </g>
# <g id="clust3" class="cluster">
# <title>cluster_2</title>
# <polygon fill="none" stroke="red" points="29.72,-112 29.72,-199 81.72,-199 81.72,-112 29.72,-112"/>
# </g>
# <!-- I -->
# <!-- 0 -->
# <g id="node2" class="node">
# <title>0</title>
# <ellipse fill="#ffffaa" stroke="black" cx="55.72" cy="-138" rx="18" ry="18"/>
# <text xml:space="preserve" text-anchor="start" x="51.6" y="-133.32" font-family="Lato" font-size="14.00">0</text>
# </g>
# <!-- I&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>I&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M0.87,-138C2.47,-138 16.17,-138 29.35,-138"/>
# <polygon fill="black" stroke="black" points="36.16,-138 29.16,-141.15 33.87,-138 29.16,-138 29.16,-138 29.16,-138 33.87,-138 29.16,-134.85 36.16,-138"/>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M49.25,-155.04C47.93,-164.86 50.09,-174 55.72,-174 59.77,-174 62.02,-169.28 62.48,-162.97"/>
# <polygon fill="black" stroke="black" points="62.23,-156.25 65.63,-163.14 62.32,-158.53 62.49,-163.25 62.49,-163.25 62.49,-163.25 62.32,-158.53 59.34,-163.36 62.23,-156.25"/>
# <text xml:space="preserve" text-anchor="start" x="38.1" y="-177.95" font-family="Lato" font-size="14.00">a &amp; !b</text>
# </g>
# <!-- 1 -->
# <g id="node3" class="node">
# <title>1</title>
# <ellipse fill="#ffffaa" stroke="black" cx="183.97" cy="-252" rx="18" ry="18"/>
# <text xml:space="preserve" text-anchor="start" x="179.85" y="-247.32" font-family="Lato" font-size="14.00">1</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M68.37,-151.01C75.02,-158.27 83.62,-167.35 91.72,-175 115.41,-197.38 144.42,-221.32 163.28,-236.45"/>
# <polygon fill="black" stroke="black" points="168.31,-240.47 160.88,-238.57 166.53,-239.05 162.84,-236.1 162.84,-236.1 162.84,-236.1 166.53,-239.05 164.81,-233.64 168.31,-240.47"/>
# <text xml:space="preserve" text-anchor="start" x="91.72" y="-227.51" font-family="Lato" font-size="14.00">b &amp; c &amp; d</text>
# </g>
# <!-- 2 -->
# <g id="node4" class="node">
# <title>2</title>
# <ellipse fill="#ffffaa" stroke="black" cx="315.97" cy="-186" rx="18" ry="18"/>
# <text xml:space="preserve" text-anchor="start" x="311.85" y="-181.32" font-family="Lato" font-size="14.00">2</text>
# </g>
# <!-- 0&#45;&gt;2 -->
# <g id="edge4" class="edge">
# <title>0&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M73.86,-140.79C111.34,-146.94 203.38,-162.4 279.97,-178 283.34,-178.69 286.88,-179.45 290.36,-180.22"/>
# <polygon fill="black" stroke="black" points="297.08,-181.74 289.56,-183.27 294.86,-181.24 290.26,-180.2 290.26,-180.2 290.26,-180.2 294.86,-181.24 290.95,-177.12 297.08,-181.74"/>
# <text xml:space="preserve" text-anchor="start" x="165.97" y="-168.15" font-family="Lato" font-size="14.00">b &amp; !d</text>
# </g>
# <!-- 3 -->
# <g id="node5" class="node">
# <title>3</title>
# <ellipse fill="#ffffaa" stroke
#45;&gt;1</title>
# <path fill="none" stroke="black" d="M306.23,-201.7C300.1,-211.29 291.03,-223.02 279.97,-230 258.93,-243.29 230.73,-248.57 210.53,-250.66"/>
# <polygon fill="black" stroke="black" points="203.62,-25

# %% [markdown]
# The `translate()` function can also be called with a formula object.  Either as a function, or as a method.

# %%
f = spot.formula('a U b'); f
# Out:
# spot.formula("a U b")

# %%
spot.translate(f)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f67283439b0> >

# %%
f.translate()
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f67283437f0> >

# %% [markdown]
# When used as a method, all the arguments are translation options.  Here is a monitor:

# %%
f.translate('mon')
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f6718724530> >

# %% [markdown]
# The following three cells show a formulas for which it makes a difference to select `'small'` or `'deterministic'`.

# %%
f = spot.formula('Ga | Gb | Gc'); f
# Out:
# spot.formula("Ga | Gb | Gc")

# %%
f.translate('buchi', 'state-based', 'small').show('.v')
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.1 (0)
#  -->
# <!-- Pages: 1 -->
# <svg width="252pt" height="205pt"
#  viewBox="0.00 0.00 252.00 205.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0) translate(4 200.94)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-200.94 247.75,-200.94 247.75,4 -4,4"/>
# <text xml:space="preserve" text-anchor="start" x="100.5" y="-179.64" font-family="Lato" font-size="14.00">[Büchi]</text>
# <!-- I -->
# <!-- 0 -->
# <g id="node2" class="node">
# <title>0</title>
# <ellipse fill="#ffffaa" stroke="black" cx="109" cy="-115.25" rx="18" ry="18"/>
# <text xml:space="preserve" text-anchor="start" x="104.88" y="-110.58" font-family="Lato" font-size="14.00">0</text>
# </g>
# <!-- I&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>I&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M109,-170.1C109,-168.5 109,-154.8 109,-141.62"/>
# <polygon fill="black" stroke="black" points="109,-134.81 112.15,-141.81 109,-137.1 109,-141.81 109,-141.81 109,-141.81 109,-137.1 105.85,-141.81 109,-134.81"/>
# </g>
# <!-- 1 -->
# <g id="node3" class="node">
# <title>1</title>
# <ellipse fill="#ffffaa" stroke="black" cx="22" cy="-22" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="22" cy="-22" rx="22" ry="22"/>
# <text xml:space="preserve" text-anchor="start" x="17.88" y="-17.32" font-family="Lato" font-size="14.00">1</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M96.9,-101.56C82.81,-86.78 59.3,-62.12 42.37,-44.37"/>
# <polygon fill="black" stroke="black" points="37.75,-39.52 44.86,-42.41 39.32,-41.17 42.58,-44.58 42.58,-44.58 42.58,-44.58 39.32,-41.17 40.3,-46.76 37.75,-39.52"/>
# <text xml:space="preserve" text-anchor="start" x="73.29" y="-65.95" font-family="Lato" font-size="14.00">a</text>
# </g>
# <!-- 2 -->
# <g id="node4" class="node">
# <title>2</title>
# <ellipse fill="#ffffaa" stroke="black" cx="109" cy="-22" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="109" cy="-22" rx="22" ry="22"/>
# <text xml:space="preserve" text-anchor="start" x="104.88" y="-17.32" font-family="Lato" font-size="14.00">2</text>
# </g>
# <!-- 0&#45;&gt;2 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M109,-97.09C109,-84.45 109,-66.98 109,-52.17"/>
# <polygon fill="black" stroke="black" points="109,-45.48 112.15,-52.48 109,-47.76 109,-52.48 109,-52.48 109,-52.48 109,-47.76 105.85,-52.48 109,-45.48"/>
# <text xml:space="preserve" text-anchor="start" x="109" y="-65.95" font-family="Lato" font-size="14.00">b</text>
# </g>
# <!-- 3 -->
# <g id="node5" class="node">
# <title>3</title>
# <ellipse fill="#ffffaa" stroke="black" cx="197" cy="-22" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="197" cy="-22" rx="22" ry="22"/>
# <text xml:space="preserve" text-anchor="start" x="192.88" y="-17.32" font-family="Lato" font-size="14.00">3</text>
# </g>
# <!-- 0&#45;&gt;3 -->
# <g id="edge4" class="edge">
# <title>0&#45;&gt;3</title>
# <path fill="none" stroke="black" d="M121.24,-101.56C135.49,-86.78 159.28,-62.12 176.4,-44.37"/>
# <polygon fill="black" stroke="black" points="181.08,-39.51 178.48,-46.74 179.49,-41.15 176.22,-44.55 176.22,-44.55 176.22,-44.55 179.49,-41.15 173.95,-42.36 181.08,-39.51"/>
# <text xml:space="preserve" text-anchor="start" x="158.27" y="-65.95" font-family="Lato" font-size="14.00">c</text>
# </g>
# <!-- 1&#45;&gt;1 -->
# <g id="edge5" class="edge">
# <title>1&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M42.58,-30.85C52.84,-32.07 62,-29.12 62,-22 62,-16.88 57.27,-13.92 50.8,-13.11"/>
# <polygon fill="black" stroke="black" points="43.8,-13.15 50.78,-9.96 46.08,-13.13 50.8,-13.11 50.8,-13.11 50.8,-13.11 46.08,-13.13 50.82,-16.26 43.8,-13.15"/>
# <text xml:space="preserve" text-anchor="start" x="62" y="-17.32" font-family="Lato" font-size="14.00">a</text>
# </g>
# <!-- 2&#45;&gt;2 -->
# <g id="edge6" class="edge">
# <title>2&#45;&gt;2</title>
# <path fill="none" stroke="black" d="
rx="22" ry="22"/>
# <text xml:space="preserve" text-anchor="start" x="97.83" y="-114.58" font-family="Lato" font-size="14.00">3</text>
# </g>
# <!-- 0&#45;&gt;3 -->
# <g id="edge4" class="edge">
# <title>0&#45;&gt;3</title>
# <path fill="none" stroke="black" d="M261.56,-210.07C238.89,-203.83 202.46,-192.35 173.71,-176.5 155.56,-166.49 137.2,-152.01 123.6,-140.24"/>
# <polygon fill="black" stroke="black" points="118.62,-135.86 125.96,-138.12 120.33,-137.36 123.88,-140.48 123.88,-140.48 123.88,-140.48 120.33,-137.36 121.79,-142.85 118.62,-135.86"/>
# <text xml:space="preserve" text-anchor="start" x="173.71" y="-163.2" font-family="Lato" font-size="14.00">!a &amp; b &amp; c</text>
# </g>
# <!-- 4 -->
# <g id="node6" class="node">
# <title>4</title>
# <ellipse fill="#ffffaa" stroke="black" cx="469.96" cy="-22" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="469.96" cy="-22" rx="22" ry="22"/>
# <text xml:space="preserve" text-anchor="start" x="465.83" y="-17.32" font-family="Lato" font-size="14.00">4</text>
# </g>
# <!-- 0&#45;&gt;4 -->
# <g id="edge5" class="edge">
# <title>0&#45;&gt;4</title>
# <path fill="none" stroke="black" d="M305.31,-216.24C352.53,-216.4 461.65,-209.07 504.96,-141.25 523.81,-111.73 504.27,-71.64 487.71,-46.55"/>
# <polygon fill="black" stroke="black" points="483.84,-40.9 490.39,-44.89 485.13,-42.78 487.79,-46.67 487.79,-46.67 487.79,-46.67 485.13,-42.78 485.19,-48.45 483.84,-40.9"/>
# <text xml:space="preserve" text-anchor="start" x="512.68" y="-114.58" font-family="Lato" font-size="14.00">a &amp; !b &amp; !c</text>
# </g>
# <!-- 5 -->
# <g id="node7" class="node">
# <title>5</title>
# <ellipse fill="#ffffaa" stroke="black" cx="213.96" cy="-119.25" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="213.96" cy="-119.25" rx="22" ry="22"/>
# <text xml:space="preserve" text-anchor="start" x="209.83" y="-114.58" font-family="Lato" font-size="14.00">5</text>
# </g>
# <!-- 0&#45;&gt;5 -->
# <g id="edge6" class="edge">
# <title>0&#45;&gt;5</title>
# <path fill="none" stroke="black" d="M267.82,-200.16C261.3,-193.2 253.79,-184.71 247.71,-176.5 240.62,-166.93 233.68,-155.79 227.97,-145.96"/>
# <polygon fill="black" stroke="black" points="224.64,-140.13 230.84,-144.64 225.77,-142.11 228.11,-146.21 228.11,-146.21 228.11,-146.21 225.77,-142.11 225.37,-147.77 224.64,-140.13"/>
# <text xml:space="preserve" text-anchor="start" x="247.71" y="-163.2" font-family="Lato" font-size="14.00">a &amp; !b &amp; c</text>
# </g>
# <!-- 6 -->
# <g id="node8" class="node">
# <title>6</title>
# <ellipse fill="#ffffaa" stroke="black" cx="423.96" cy="-119.25" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="423.96" cy="-119.25" rx="22" ry="22"/>
# <text xml:space="preserve" text-anchor="start" x="419.83" y="-114.58" font-family="Lato" font-size="14.00">6</text>
# </g>
# <!-- 0&#45;&gt;6 -->
# <g id="edge7" class="edge">
# <title>0&#45;&gt;6</title>
# <path fill="none" stroke="black" d="M301.1,-203.24C326.06,-186.38 371.08,-155.97 399.14,-137.02"/>
# <polygon fill="black" stroke="black" points="404.87,-133.14 400.84,-139.67 402.98,-134.42 399.07,-137.06 399.07,-137.06 399.07,-137.06 402.98,-134.42 397.31,-134.45 404.87,-133.14"/>
# <text xml:space="preserve" text-anchor="start" x="366.09" y="-163.2" font-family="Lato" font-size="14.00">a &amp; b &amp; !c</text>
# </g>
# <!-- 1&#45;&gt;1 -->
# <g id="edge9" class="edge">
# <title>1&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M118.54,-30.85C128.8,-32.07 137.96,-29.12 137.96,-22 137.96,-16.88 133.23,-13.92 126.76,-13.11"/>
# <polygon fill="black" stroke="black" points="119.76,-13.15 126.74,-9.96 122.04,-13.13 126.76,-13.11 126.76,-13.11 126.76,-13.11 122.04,-13.13 126.77,-16.26 119.76,-13.15"/>
# <text xml:space="preserve" text-anchor="start" x="137.96" y="-17.32" font-family="Lato" font-size="14.00">c</text>
# </g>
# <!-- 2&#45;&gt;2 -->
# <g id="edge10" class="edge">
# <title>2&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M341.54,-30.85C351.8,-32.07 360.96,-29.12 360.96,-22 360.96,-16.88 356.23,-13.92 349.76,-13.11"/>
# <polygon fill="black" stroke="black" points="342.76,-13.15 349.74,-9.96 345.04,-13.13 349.76,-13.11 349.76,-13.11 349.76,-13.11 345.04,-13.13 349.77,-16.26 342.76,-13.15"/>
# <text xml:space="preserve" text-anchor="start" x="36

# %% [markdown]
# Here is how to build an unambiguous automaton:

# %%
spot.translate('GFa -> GFb', 'unambig')
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f672a8480b0> >

# %% [markdown]
# Compare with the standard translation:

# %%
spot.translate('GFa -> GFb')
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f6718725d70> >

# %% [markdown]
# And here is the automaton above with state-based acceptance:

# %%
a = spot.translate('GFa -> GFb', 'sbacc')
a
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f6718726230> >

# %% [markdown]
# Some example of running the self-loopization algorithm on an automaton:

# %%
a.is_empty()
# Out:
# False

# %% [markdown]
# Reading from file (see `automaton-io.ipynb` for more examples).

# %%
# %%file example1.aut
# HOA: v1
# States: 3
# Start: 0
# AP: 2 "a" "b"
# acc-name: Buchi
# Acceptance: 5 Inf(0)&Fin(1)&Fin(4) | Inf(2)&Inf(3) | Inf(1)
# --BODY--
# State: 0 {3}
# [t] 0
# [0] 1 {1}
# [!0] 2 {0 4}
# State: 1 {3}
# [1] 0
# [0&1] 1 {0}
# [!0&1] 2 {2 4}
# State: 2
# [!1] 0
# [0&!1] 1 {0}
# [!0&!1] 2 {0 4}
# --END--
# Out:
# Writing example1.aut

# %%
a = spot.automaton('example1.aut')
display(a)
display(spot.remove_fin(a))
display(a.postprocess('GeneralizedBuchi', 'complete'))
display(a.postprocess('Buchi', "SBAcc"))
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f6718728670> >
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f6728342f30> >
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f67281c7db0> >
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f67281c7db0> >

# %%
# !rm example1.aut

# %%
spot.complete(a)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f671873e730> >

# %%
spot.complete(spot.translate('Ga'))
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f671873f3f0> >

# %%
spot.formula('(a W c) & FGa').is_syntactic_persistence()
# Out:
# True

# %%
# Using +1 in the display options is a convenient way to shift the 
# set numbers in the output, as an aid in reading the product.
a1 = spot.translate('GF(a <-> Xa)')
a2 = spot.translate('a U b & GFc')
display_inline(a1.show('.t'), a2.show('.t+1'))
# the product should display pairs of states, unless asked not to (using '1').
p = spot.product(a1, a2)
display_inline(p.show('.t'), p.show('.t1'), per_row=2)
# Out:
# <div style='vertical-align:text-top;display:inline-block;'><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.1 (0)
#  -->
# <!-- Pages: 1 -->
# <svg width="164pt" height="137pt"
#  viewBox="0.00 0.00 164.00 137.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0) translate(4 132.97)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-132.97 160.22,-132.97 160.22,4 -4,4"/>
# <text xml:space="preserve" text-anchor="start" x="58.24" y="-112.67" font-family="Lato" font-size="14.00">Inf(</text>
# <text xml:space="preserve" text-anchor="start" x="78.49" y="-112.67" font-family="Lato" font-size="14.00" fill="#1f78b4">⓿</text>
# <text xml:space="preserve" text-anchor="start" x="94.24" y="-112.67" font-family="Lato" font-size="14.00">)</text>
# <text xml:space="preserve" text-anchor="start" x="56.74" y="-98.67" font-family="Lato" font-size="14.00">[Büchi]</text>
# <!-- I -->
# <!-- 0 -->
# <g id="node2" class="node">
# <title>0</title>
# <ellipse fill="#ffffaa" stroke="black" cx="55.72" cy="-22.47" rx="18" ry="18"/>
# <text xml:space="preserve" text-anchor="start" x="51.6" y="-17.8" font-family="Lato" font-size="14.00">0</text>
# </g>
# <!-- I&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>I&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M0.87,-22.47C2.47,-22.47 16.17,-22.47 29.35,-22.47"/>
# <polygon fill="black" stroke="black" points="36.16,-22.47 29.16,-25.62 33.87,-22.47 29.16,-22.47 29.16,-22.47 29.16,-22.47 33.87,-22.47 29.16,-19.32 36.16,-22.47"/>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M49.25,-39.51C47.93,-49.33 50.09,-58.47 55.72,-58.47 59.77,-58.47 62.02,-53.75 62.48,-47.45"/>
# <polygon fill="black" stroke="black" points="62.23,-40.73 65.63,-47.61 62.32,-43.01 62.49,-47.72 62.49,-47.72 62.49,-47.72 62.32,-43.01 59.34,-47.84 62.23,-40.73"/>
# <text xml:space="preserve" text-anchor="start" x="52.35" y="-79.67" font-family="Lato" font-size="14.00">a</text>
# <text xml:space="preserve" text-anchor="start" x="47.85" y="-62.42" font-family="Lato" font-size="14.00" fill="#1f78b4">⓿</text>
# </g>
# <!-- 1 -->
# <g id="node3" class="node">
# <title>1</title>
# <ellipse fill="#ffffaa" stroke="black" cx="138.22" cy="-22.47" rx="18" ry="18"/>
# <text xml:space="preserve" text-anchor="start" x="134.1" y="-17.8" font-family="Lato" font-size="14.00">1</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M74.19,-22.47C85.16,-22.47 99.5,-22.47 111.72,-22.47"/>
# <polygon fill="black" stroke="black" points="118.57,-22.47 111.57,-25.62 116.29,-22.47 111.57,-22.47 111.57,-22.47 111.57,-22.47 116.29,-22.47 111.57,-19.32 118.57,-22.47"/>
# <text xml:space="preserve" text-anchor="start" x="91.72" y="-26.42" font-family="Lato" font-size="14.00">!a</text>
# </g>
# <!-- 1&#45;&gt;0 -->
# <g id="edge4" class="edge">
# <title>1&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M123.4,-11.68C117.27,-7.55 109.75,-3.33 102.22,-1.22 93.48,1.22 84.32,-1.84 76.53,-6.33"/>
# <polygon fill="black" stroke="black" points="70.83,-10.07 74.95,-3.59 72.74,-8.82 76.68,-6.23 76.68,-6.23 76.68,-6.23 72.74,-8.82 78.41,-8.86 70.83,-10.07"/>
# <text xml:space="preserve" text-anchor="start" x="93.6" y="-5.17" font-family="Lato" font-size="14.00">a</text>
# </g>
# <!-- 1&#45;&gt;1 -->
# <g id="edge5" class="edge">
# <title>1&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M130.97,-39.14C129.36,-49.1 131.77,-58.47 138.22,-58.47 142.85,-58.47 145.4,-53.63 145.87,-47.21"/>
# <polygon fill="black" stroke="black" points="145.53,-40.35 149.03,-47.19 145.65,-42.63 145.88,-47.35 145.88,-47.35 145.88,-47.35 145.65,-42.63 142.74,-47.5 145.53,-40.35"/>
# <text xml:space="preserve" text-anchor="start" x="132.97" y="-79.67" font-family="Lato" font-size="14.00">!a</text>
# <text xml:space="preserve" text-anchor="start" x="130.35" y="-62.42" font-family="Lato" font-size="14.00" fill="#1f78b4">⓿</text>
# </g>
# </g>
# </svg>
# </div><div style='vertical-align:text-top;display:inline-block;'><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.1 (0)
#  -->
# <!-- Pages: 1 -->
# <svg width="161pt" height="168pt"
#  viewBox="0.00 0.00 161.00 168.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0) translate(4 163.75)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-163.75 157.22,-163.75 157.22,4 -4,4"/>
# <text xml:space="preserve" text-anchor="start" x="56.74" y="-143.45" font-family="Lato" font-size="14.00">Inf(</text>
# <text xml:space="preserve" text-anchor="start" x="76.99" y="-143.45" font-family="Lato" font-size="14.00" fill="#ff4da0">❶</text>
# <text xml:space="preserve" text-anchor="start" x="92.74" y="-143.45" font-family="Lato" font-size="14.00">)</text>
# <text xml:space="preserve" text-anchor="start" x="55.24" y="-129.45" font-family="Lato" font-size="14.00">[Büchi]</text>
# <!-- I -->
# <!-- 0 -->
# <g id="node2" class="node">
# <title>0</title>
# <ellipse fill="#ffffaa" stroke="black" cx="55.72" cy="-18" rx="18" ry="18"/>
# <text xml:space="preserve" text-anchor="start" x="51.6" y="-13.32" font-family="Lato" font-size="14.00">0</text>
# </g>
# <!-- I&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>I&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M0.87,-18C2.47,-18 16.17,-18 29.35,-18"/>
# <polygon fill="black" stroke="black" points="36.16,-18 29.16,-21.15 33.87,-18 29.16,-18 29.16,-18 29.16,-18 33.87,-18 29.16,-14.85 36.16,-18"/>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M49.25,-35.04C47.93,-44.86 50.09,-54 55.72,-54 59.77,-54 62.02,-49.28 62.48,-42.97"/>
# <polygon fill="black" stroke="black" points="62.23,-36.25 65.63,-43.14 62.32,-38.53 62.49,-43.25 62.49,-43.25 62.49,-43.25 62.32,-38.53 59.34,-43.36 62.23,-36.25"/>
# <text xml:space="preserve" text-anchor="start" x="38.1" y="-57.95" font-family="Lato" font-size="14.00">a &amp; !b</text>
# </g>
# <!-- 1 -->
# <g id="node3" class="node">
# <title>1</title>
# <ellipse fill="#ffffaa" stroke="black" cx="135.22" cy="-18" rx="18" ry="18"/>
# <text xml:space="preserve" text-anchor="start" x="131.1" y="-13.32" font-family="Lato" font-size="14.00">1</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M73.92,-18C84.18,-18 97.4,-18 108.85,-18"/>
# <polygon fill="black" stroke="black" points="115.58,-18 108.58,-21.15 113.3,-18 108.58,-18 108.58,-18 108.58,-18 113.3,-18 108.58,-14.85 115.58,-18"/>
# <text xml:space="preserve" text-anchor="start" x="91.72" y="-21.95" font-family="Lato" font-size="14.00">b</text>
# </g>
# <!-- 1&#45;&gt;1 -->
# <g id="edge4" class="edge">
# <title>1&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M131.65,-35.78C131.04,-45.31 132.23,-54 135.22,-54 137.32,-54 138.53,-49.71 138.86,-43.84"/>
# <polygon fill="black" stroke="black" points="138.8,-37 142.01,-43.97 138.82,-39.28 138.86,-44 138.86,-44 138.86,-44 138.82,-39.28 135.71,-44.03 138.8,-37"/>
# <text xml:space="preserve" text-anchor="start" x="129.97" y="-57.95" font-family="Lato" font-size="14.00">!c</text>
# </g>
# <!-- 1&#45;&gt;1 -->
# <g id="edge5" class="edge">
# <title>1&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M129.35,-35.42C126,-52.79 127.96,-72 135.22,-72 141.4,-72 143.74,-58.07 142.23,-43.21"/>
# <polygon fill="black" stroke="black" points="141.27,-36.63 145.4,-43.1 141.6,-38.88 142.28,-43.55 142.28,-43.55 142.28,-43.55 141.6,-38.88 139.16,-44.01 141.27,-36.63"/>
# <text xml:space="preserve" text-anchor="start" x="131.85" y="-93.2" font-family="Lato" font-size="14.00">c</text>
# <text xml:space="preserve" text-anchor="st
# <div style='vertical-align:text-top;display:inline-block;width:50%;'><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.1 (0)
#  -->
# <!-- Pages: 1 -->
# <svg width="337pt" height="254pt"
#  viewBox="0.00 0.00 337.00 254.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0) translate(4 249.5)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-249.5 332.89,-249.5 332.89,4 -4,4"/>
# <text xml:space="preserve" text-anchor="start" x="119.82" y="-229.2" font-family="Lato" font-size="14.00">Inf(</text>
# <text xml:space="preserve" text-anchor="start" x="140.07" y="-229.2" font-family="Lato" font-size="14.00" fill="#1f78b4">⓿</text>
# <text xml:space="preserve" text-anchor="start" x="155.82" y="-229.2" font-family="Lato" font-size="14.00">)&amp;Inf(</text>
# <text xml:space="preserve" text-anchor="start" x="189.57" y="-229.2" font-family="Lato" font-size="14.00" fill="#ff4da0">❶</text>
# <text xml:space="preserve" text-anchor="start" x="205.32" y="-229.2" font-family="Lato" font-size="14.00">)</text>
# <text xml:space="preserve" text-anchor="start" x="122.44" y="-215.2" font-family="Lato" font-size="14.00">[gen. Büchi 2]</text>
# <!-- I -->
# <!-- 0 -->
# <g id="node2" class="node">
# <title>0</title>
# <ellipse fill="#ffffaa" stroke="black" cx="62.62" cy="-18" rx="24.9" ry="18"/>
# <text xml:space="preserve" text-anchor="start" x="52.87" y="-13.32" font-family="Lato" font-size="14.00">0,0</text>
# </g>
# <!-- I&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>I&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M1.11,-18C3.46,-18 16.09,-18 29.21,-18"/>
# <polygon fill="black" stroke="black" points="36.14,-18 29.14,-21.15 33.86,-18 29.14,-18 29.14,-18 29.14,-18 33.86,-18 29.14,-14.85 36.14,-18"/>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M54.87,-35.41C53.43,-45.09 56.01,-54 62.62,-54 67.27,-54 69.93,-49.59 70.59,-43.61"/>
# <polygon fill="black" stroke="black" points="70.4,-36.63 73.74,-43.54 70.47,-38.91 70.59,-43.63 70.59,-43.63 70.59,-43.63 70.47,-38.91 67.45,-43.71 70.4,-36.63"/>
# <text xml:space="preserve" text-anchor="start" x="45" y="-75.2" font-family="Lato" font-size="14.00">a &amp; !b</text>
# <text xml:space="preserve" text-anchor="start" x="54.75" y="-57.95" font-family="Lato" font-size="14.00" fill="#1f78b4">⓿</text>
# </g>
# <!-- 1 -->
# <g id="node3" class="node">
# <title>1</title>
# <ellipse fill="#ffffaa" stroke="black" cx="179.93" cy="-93" rx="24.9" ry="18"/>
# <text xml:space="preserve" text-anchor="start" x="170.18" y="-88.33" font-family="Lato" font-size="14.00">0,1</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="
text>
# </g>
# <!-- 2&#45;&gt;1 -->
# <g id="edge9" class="edge">
# <title>2&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M279.07,-90.82C273.19,-90.38 266.91,-89.98 261.08,-89.75 244.09,-89.09 239.82,-89.09 222.83,-89.75 219.64,-89.87 216.32,-90.05 213,-90.26"/>
# <polygon fill="black" stroke="black" points="206.06,-90.74 212.82,-87.11 208.33,-90.58 213.04,-90.25 213.04,-90.25 213.04,-90.25 208.33,-90.58 213.26,-93.4 206.06,-90.74"/>
# <text xml:space="preserve" text-anchor="start" x="224.71" y="-93.7" font-family="Lato" font-size="14.00">a &amp; !c</text>
# </g>
# <!-- 2&#45;&gt;1 -->
# <g id="edge10" class="edge">
# <title>2&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M292.23,-76.89C284.77,-67.25 273.89,-55.86 261.08,-50.5 245.4,-43.94 238.51,-43.94 222.83,-50.5 212.62,-54.77 203.64,-62.87 196.64,-70.87"/>
# <polygon fill="black" stroke="black" points="192.45,-75.95 194.47,-68.55 193.9,-74.19 196.9,-70.55 196.9,-70.55 196.9,-70.55 193.9,-74.19 199.33,-72.55 192.45,-75.95"/>
# <text xml:space="preserve" text-anchor="start" x="226.58" y="-71.7" font-family="Lato" font-size="14.00">a &amp; c</text>
# <text xml:space="preserve" text

# %% [markdown]
# Explicit determinization after translation:

# %%
a = spot.translate('FGa')
display(a)
display(a.is_deterministic())
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f6718753f30> >
# False

# %%
spot.tgba_determinize(a)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f67283429f0> >

# %% [markdown]
# Determinization by `translate()`.  The `generic` option allows any acceptance condition to be used instead of the default generalized Büchi.

# %%
spot.translate('FGa', 'generic', 'deterministic')
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f6728210430> >

# %% [markdown]
# Translation to state-based co-Büchi automaton

# %%
spot.translate('FGa', 'coBuchi', 'deterministic', 'sbacc').show('.b')
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.1 (0)
#  -->
# <!-- Pages: 1 -->
# <svg width="164pt" height="122pt"
#  viewBox="0.00 0.00 164.00 122.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0) translate(4 117.75)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-117.75 160.22,-117.75 160.22,4 -4,4"/>
# <text xml:space="preserve" text-anchor="start" x="57.11" y="-97.45" font-family="Lato" font-size="14.00">Fin(</text>
# <text xml:space="preserve" text-anchor="start" x="79.61" y="-97.45" font-family="Lato" font-size="14.00" fill="#1f78b4">⓿</text>
# <text xml:space="preserve" text-anchor="start" x="95.36" y="-97.45" font-family="Lato" font-size="14.00">)</text>
# <text xml:space="preserve" text-anchor="start" x="46.99" y="-83.45" font-family="Lato" font-size="14.00">[co&#45;Büchi]</text>
# <!-- I -->
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <path fill="#ffffaa" stroke="black" d="M61.72,-42.5C61.72,-42.5 49.72,-42.5 49.72,-42.5 43.72,-42.5 37.72,-36.5 37.72,-30.5 37.72,-30.5 37.72,-12 37.72,-12 37.72,-6 43.72,0 49.72,0 49.72,0 61.72,0 61.72,0 67.72,0 73.72,-6 73.72,-12 73.72,-12 73.72,-30.5 73.72,-30.5 73.72,-36.5 67.72,-42.5 61.72,-42.5"/>
# <text xml:space="preserve" text-anchor="start" x="51.6" y="-25.2" font-family="Lato" font-size="14.00">1</text>
# <text xml:space="preserve" text-anchor="start" x="47.85" y="-7.95" font-family="Lato" font-size="14.00" fill="#1f78b4">⓿</text>
# </g>
# <!-- I&#45;&gt;1 -->
# <g id="edge1" class="edge">
# <title>I&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M0.87,-21.25C2.47,-21.25 16.17,-21.25 29.35,-21.25"/>
# <polygon fill="black" stroke="black" points="36.16,-21.25 29.16,-24.4 33.87,-21.25 29.16,-21.25 29.16,-21.25 29.16,-21.25 33.87,-21.25 29.16,-18.1 36.16,-21.25"/>
# </g>
# <!-- 1&#45;&gt;1 -->
# <g id="edge4" class="edge">
# <title>1&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M48.98,-42.65C48.34,-52.22 50.59,-60.5 55.72,-60.5 59.33,-60.5 61.51,-56.41 62.26,-50.65"/>
# <polygon fill="black" stroke="black" points="62.43,-43.87 65.41,-50.94 62.37,-46.15 62.26,-50.86 62.26,-50.86 62.26,-50.86 62.37,-46.15 59.11,-50.79 62.43,-43.87"/>
# <text xml:space="preserve" text-anchor="start" x="50.47" y="-64.45" font-family="Lato" font-size="14.00">!a</text>
# </g>
# <!-- 0 -->
# <g id="node3" class="node">
# <title>0</title>
# <path fill="#ffffaa" stroke="black" d="M144.22,-39.25C144.22,-39.25 132.22,-39.25 132.22,-39.25 126.22,-39.25 120.22,-33.25 120.22,-27.25 120.22,-27.25 120.22,-15.25 120.22,-15.25 120.22,-9.25 126.22,-3.25 132.22,-3.25 132.22,-3.25 144.22,-3.25 144.22,-3.25 150.22,-3.25 156.22,-9.25 156.22,-15.25 156.22,-15.25 156.22,-27.25 156.22,-27.25 156.22,-33.25 150.22,-39.25 144.22,-39.25"/>
# <text xml:space="preserve" text-anchor="start" x="134.1" y="-16.57" font-family="Lato" font-size="14.00">0</text>
# </g>
# <!-- 1&#45;&gt;0 -->
# <g id="edge5" class="edge">
# <title>1&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M74.19,-21.25C85.16,-21.25 99.5,-21.25 111.72,-21.25"/>
# <polygon fill="black" stroke="black" points="118.57,-21.25 111.57,-24.4 116.29,-21.25 111.57,-21.25 111.57,-21.25 111.57,-21.25 116.29,-21.25 111.57,-18.1 118.57,-21.25"/>
# <text xml:space="preserve" text-anchor="start" x="93.6" y="-25.2" font-family="Lato" font-size="14.00">a</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M119.93,-8.05C111.6,-3.25 101.36,0.48 91.72,-2 88.23,-2.9 84.71,-4.23 81.31,-5.77"/>
# <polygon fill="black" stroke="black" points="75.24,-8.87 80.05,-2.88 77.28,-7.83 81.48,-5.69 81.48,-5.69 81.48,-5.69 77.28,-7.83 82.91,-8.49 75.24,-8.87"/>
# <text xml:space="preserve" text-anchor="start" x="91.72" y="-5.95" font-family="Lato" font-size="14.00">!a</text>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M130.76,-39.4C129.61,-48.79 132.1,-57.25 138.22,-57.25 142.53,-57.25 145.03,-53.07 145.74,-47.32"/>
# <polygon fill="black" stroke="black" points="145.69,-40.62 148.9,-47.6 145.71,-42.9 145.75,-47.62 145.75,-47.62 145.75,-47.62 145.71,-42.9 142.6,-47.65 145.69,-40.62"/>
# <text xml:space="preserve" text-anchor="start" x="134.85" y="-61.2" font-family="Lato" font-size="14.00">a</text>
# </g>
# </g>
# </svg>

# %% [markdown]
# Translation to parity automaton.  Specifying just `parity max odd` requires a parity acceptance.  Adding `colored` ensures that each transition (or state if `sbacc` is also given) has a color, as people usually expect in parity automata.

# %%
spot.translate('FGa', 'parity max odd', 'colored')
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f6718752eb0> >

# %% [markdown]
# Adding an atomic proposition to all edges

# %%
import buddy
display(a)
b = buddy.bdd_ithvar(a.register_ap('b'))
for e in a.edges():
    e.cond &= b
display(a)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f6718753f30> >
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f6718753f30> >

# %% [markdown]
# Adding an atomic proposition to the edge between 0 and 1:

# %%
c = buddy.bdd_ithvar(a.register_ap('c'))
for e in a.out(0):
    if e.dst == 1:
        e.cond &= c
a
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f6718753f30> >
